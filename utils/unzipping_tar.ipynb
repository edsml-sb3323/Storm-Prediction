# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/edsmlproj2')

# %%
import tarfile

# Replace 'your_file.tgz' with the actual file name
file_path = 'all_storm_image.tgz'

# Open the .tgz file
with tarfile.open(file_path, 'r:gz') as tar:
    tar.extractall()

# %%
os.listdir()
# Out:
# ['storm_data_csv',
#  'all_storm_image.tgz',
#  'unzipping_tar.ipynb',
#  'Selected_Storms_curated',
#  'combined_storm.csv',
#  'combining_csv.ipynb',
#  'combined_storm_updated.csv',
#  'data_extraction.ipynb',
#  'model-outputs',
#  'logs',
#  'data_exploration.ipynb',
#  'all_storm_image']

# %%
# %cd /content/drive/MyDrive/edsmlproj2/all_storm_image
# Out:
# /content/drive/MyDrive/edsmlproj2/all_storm_image

# %%
# !ls | wc -l
# Out:
# 9528
